# %% [markdown]
# <a href="https://colab.research.google.com/github/karnamohit/CodingHomework-Example/blob/master/tf1_test_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing all the useful libraries...

# %%
# %tensorflow_version 1.x
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Checking the version of TensorFlow, NumPy...

# %%
#print('TensorFlow version info:\t',tf.__version__)
# !pip show tensorflow
print(' ')
print('------------------------------------------------------------')
print(' ')
# !pip show numpy
#print('NumPy version info:\t \t',np.__version__)
# Out:
# Name: tensorflow
# Version: 1.15.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: tensorflow-estimator, keras-applications, termcolor, keras-preprocessing, numpy, gast, wrapt, google-pasta, grpcio, wheel, tensorboard, six, protobuf, absl-py, opt-einsum, astor
# Required-by: stable-baselines, magenta, fancyimpute
#
# ------------------------------------------------------------
#
# Name: numpy
# Version: 1.17.3
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email: None
# License: BSD
# Location: /usr/local/lib/python3.6/dist-packages
# Requires:
# Required-by: yellowbrick, xgboost, xarray, wordcloud, umap-learn, torchvision, torchtext, torch, thinc, Theano, tflearn, tensorflow, tensorflow-probability, tensorflow-hub, tensorflow-datasets, tensorboard, tensor2tensor, tables, statsmodels, stable-baselines, spacy, sklearn-pandas, seaborn, scs, scipy, scikit-learn, resampy, PyWavelets, pystan, pysndfile, pymc3, pyemd, pyarrow, pretty-midi, plotnine, patsy, pandas, osqp, opt-einsum, opencv-python, opencv-contrib-python, numexpr, numba, np-utils, nibabel, moviepy, mlxtend, mizani, missingno, mir-eval, matplotlib, matplotlib-venn, magenta, lucid, lightgbm, librosa, knnimpute, kfac, Keras, Keras-Preprocessing, Keras-Applications, kapre, jpeg4py, jaxlib, jax, imgaug, imbalanced-learn, imageio, hyperopt, h5py, gym, graph-nets, gensim, folium, fix-yahoo-finance, featuretools, fbprophet, fastdtw, fastai, fancyimpute, fa2, ecos, daft, cvxpy, cupy-cuda100, cufflinks, chainer, Bottleneck, bokeh, blis, autograd, atari-py, astropy, altair, albumentations

# %% [markdown]
# **Making, processing raw data**

# %% [markdown]
# Make up data (2x2, sequentially indexed matrices)...

# %%
series_data = np.zeros((100,2,2), np.float64)        # "time"-series data for a 2x2 evolving matrix with 100 time-steps, randomly initialized
for i in range(series_data.shape[0]):
    series_data[i,:,:] = (i**0.5)*3 + 5
#print(series_data)
tsteps = int(series_data.shape[0])         # total number of time-steps in the series
tsteps_train = int(tsteps/2)               # number of time-steps used for training
mat_row = int(series_data.shape[1])
mat_col = int(series_data.shape[2])

#print(series_data[tsteps_train-2,:,:])
#print(series_data[tsteps_train-1,:,:])
#print(series_data[tsteps_train,:,:])

# %% [markdown]
# Define a sequence (multiple consecutive 2x2 matrices) size, ```len_seq```, to be fed in as input (equivalent to the amount of memory in previous time-steps, in our case), and the amount of overlap, ```n_overlap``` between any two adjacent input sequences...

# %%
len_seq = 4
n_overlap = 3

if (n_overlap >= len_seq):
    raise Exception("n_overlap must be less than len_seq")

# %% [markdown]
# Build tensor of sequences, call it ```seq_series_data```...

# %%
n_seq = int((tsteps_train - (len_seq - n_overlap)) / (len_seq - n_overlap)) # number of sequences of size len_seq
#print(n_seq)
seq_series_data = np.zeros((n_seq,len_seq,mat_row,mat_col), np.float64)
seq_series_data_pred = np.zeros((1,mat_row,mat_col), np.float64)
#print(seq_series_data_pred)
i = 0
#j = 0
k = 0
while (i <= n_seq):           # the training sequences start at time-step 1 (series_data[0] element) in this case
    try:
        for j in range(len_seq - 1):
            seq_series_data[k,j,:,:] = series_data[i+j,:,:]
    except IndexError:
        break
    #print(seq_series_data[k,:,:,:])
    #print(j)
    seq_series_data_pred = np.append(seq_series_data_pred, series_data[i+j+1:i+j+2,:,:], axis = 0)
    i += len_seq - n_overlap
    #j += 1
    k += 1
    #print(k,i)
seq_series_data_pred = np.delete(seq_series_data_pred, seq_series_data_pred[0,:,:], axis=0) # true output
#print(seq_series_data_pred)
#print(type(seq_series_data))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future

# %%
# test to check data-type and shape of seq_series_data, seq_series_data_pred, and a slice seq_series_data

print('shape of X (excluding the true output): ',seq_series_data[0,:-1,:,:].shape) 
print('no. of batches of X: ', seq_series_data.shape[0]) # 1 - prints the number of time-steps, each of these associated with a sequence of 2x2 matrices
#print(seq_series_data[0].shape)
print('shape of Y_pred and Y_true: ', seq_series_data_pred[:1,:,:].shape)
print('no. of predictions (equal to the no. of batches of X): ', seq_series_data_pred.shape[0]) 
            # 2 - prints the number of time-steps, each of these assocaited with one 2x2 matrix (model truth), must match 1 above
print('shape of X (excluding the true output): ', seq_series_data[0,:-1,:,:].shape) # prints the sequence-size used per prediction
# Out:
# shape of X (excluding the true output):  (3, 2, 2)
# no. of batches of X:  49
# shape of Y_pred and Y_true:  (1, 2, 2)
# no. of predictions (equal to the no. of batches of X):  49
# shape of X (excluding the true output):  (3, 2, 2)

# %% [markdown]
# **Building a model**

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# %% [markdown]
# Define architectural (hyper-)parameters...

# %%
# define layers with #(nodes/layer), n_units_i, connected by weight matrices, w_i, and bias matrices, b_i

n_inp_n = series_data[:tsteps_train,:,:].shape[0]   # no. of 2x2 matrices fed as input ("units" per INPUT layer)
n_units_1 = 4   # no. of units in the first hidden layer
#n_units_2 = 8
#n_units_3 = 4
n_units_1_conv = n_units_1
            # no. of (convolution) units in the output layer; must equal the number of units in the immediately preceding hidden layer
n_outp_n  = np.expand_dims(series_data[-1,:,:], 0).shape[0]
            # number of (2x2) tensors the model must output (the same size as the sequence-size of the model output, 1 in the current case)

# %% [markdown]
# Define activation functions, operations, etc. ...

# %%
# using "activation=None" (linear operation) in tf.layers.dense for hidden layer h_1

def softplus(z, name="softplus"):
    return tf.math.softplus(z)

def exponential(z, name="exponential"):
    return tf.math.exp(z)

def square(z, name="square"):
    return tf.math.square(z)

def expinv(z, name="expinv"):
    return tf.math.exp(-z)

def inv(z, name="inv"):
    return tf.math.square(tf.math.sqrt(1/z))

'''# using a convolution operation (with a custom filter), conv_3D, for hidden layer h_2

# define a custom filter, filter_1, to be used with the one-shot (stride-less) convolution operation, conv_3D_oneshot
#     ignoring padding for now
def filter_1(d, h, w):
    # the latest sequence gets the highest contribution
    filter = np.zeros((d, h, w), np.float64)
    for i in range(d):
        for j in range(h):
            for k in range(w):
                filter[i,j,k] = np.sqrt(np.exp(d))
    return tf.convert_to_tensor(filter, dtype=tf.int32)

# define a (stride-less) function for the convolution operation
def conv_3D_oneshot(z, name="custom_conv_3D_1"):
    shape = z.get_shape().as_list()
    depth = shape[0].value
    height = shape[1].value
    width = shape[2].value
    filter = filter_1(depth, height, width)
    return tf.math.reduce_sum(tf.math.multiply(z, filter), 0)'''
# Out:
# '# using a convolution operation (with a custom filter), conv_3D, for hidden layer h_2\n\n# define a custom filter, filter_1, to be used with the one-shot (stride-less) convolution operation, conv_3D_oneshot\n#     ignoring padding for now\ndef filter_1(d, h, w):\n    # the latest sequence gets the highest contribution\n    filter = np.zeros((d, h, w), np.float64)\n    for i in range(d):\n        for j in range(h):\n            for k in range(w):\n                filter[i,j,k] = np.sqrt(np.exp(d))\n    return tf.convert_to_tensor(filter, dtype=tf.int32)\n\n# define a (stride-less) function for the convolution operation\ndef conv_3D_oneshot(z, name="custom_conv_3D_1"):\n    shape = z.get_shape().as_list()\n    depth = shape[0].value\n    height = shape[1].value\n    width = shape[2].value\n    filter = filter_1(depth, height, width)\n    return tf.math.reduce_sum(tf.math.multiply(z, filter), 0)'

# %%
n_inp_n
# Out:
# 50

# %% [markdown]
# Construct input placeholders for the model...

# %%
reset_graph()

X = tf.placeholder(tf.float64, shape=(None, mat_row, mat_col, 1), name='input')    # raw input (?x2x2)
#X_in = tf.expand_dims(X,-1)
#x1 = tf.math.exp(X)    # model input (modified raw input) (3x2x2)
# Y_pred = tf.placeholder(tf.float64, shape=(None, mat_row, mat_col),name='model_output')
            # model output: predicting a 2x2 matrix "?" time-step(s) at a time
Y_true = tf.placeholder(tf.float64, shape=(None, mat_row, mat_col),name='true_output')   # true output: same shape as the model output
#dim_in = tf.placeholder(tf.int64, shape=(1), name='len_inp')
#dim_out = tf.placeholder(tf.int64,shape=(1), name='len_out')
X.get_shape()
# Out:
# TensorShape([Dimension(None), Dimension(2), Dimension(2), Dimension(1)])

# %% [markdown]
# Build the layers...

# %%
with tf.name_scope("ann_1"):    # test ANN model, "ann_1"
    h_1 = tf.layers.dense(X, n_units_1, activation=tf.nn.relu, use_bias=True, name="hidden_layer_1")    # first hidden layer (linear activation)
    #h_2 = tf.layers.dense(h_1, n_units_2, activation=None, use_bias=False, name="hidden_layer_2")
    #h_3 = tf.layers.dense(h_2, n_units_3, activation=None, use_bias=False, name="hidden_layer_3")
    f_1 = tf.get_variable("inp_to_outp_1", [4, 1], trainable=True, dtype=tf.float64)    # "filter" with zero strides, for "one-shot convolution"
    hf_1 = tf.tensordot(h_1, f_1, axes = 1, name="hidden_funnel_layer_1")   # funneling layer, to reduce input dimensions to output dimensions 
    h_o = tf.layers.dense(hf_1, n_outp_n, activation=None, use_bias=True, name="output_layer")    # output layer
    Y_pred = tf.squeeze(h_o, [3])    # model output
# Out:
# WARNING:tensorflow:From <ipython-input-10-2b3ab53eee04>:2: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.

# %%
Y_pred.shape
# Out:
# TensorShape([Dimension(None), Dimension(2), Dimension(2)])

# %% [markdown]
# Define the loss function...

# %%
with tf.name_scope("loss_ann_1"):   # loss function for the model "ann_1"
    loss = tf.losses.mean_squared_error(Y_pred, Y_true)   # element-wise MSE
    #loss = tf.math.reduce_mean(accuracy)    # the mean of the elements of the MSE tensor, computed above as "accuracy"
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
#accuracy.get_shape().as_list()

# %% [markdown]
# Choose the optimization algorithm to be used...

# %%
learn_rate = 0.001    # hyper-parameter for updating a variable v: v_new = v_old + delta_v = v_old - learn_rate*grad_v(loss)

with tf.name_scope("opt_ann_1"):    # optimizer for "ann_1"
    opt = tf.train.GradientDescentOptimizer(learn_rate)   # use the gradient descent optimization algorithm
    loss_min = opt.minimize(loss)   # operation to minimize "loss"

# %% [markdown]
# Set up initializer and session-saver objects (required for assigning initial values to the ```tf.Graph``` variables and saving the values of variables optimized in the session)...

# %%
init = tf.global_variables_initializer()    # initialize the model variables
saver = tf.train.Saver()    # saves the updated parameters from a session run

# %% [markdown]
# **Running the model**

# %% [markdown]
# Assigning no. of training cycles, batch-sizes, etc. ...

# %%
n_epoch = 10000   # number of optimization steps on the WHOLE training dataset

# %%
print(series_data.shape)
inp = np.expand_dims(series_data[:99,:,:],-1)
out = series_data[1:,:,:]
print(inp.shape)
print(out.shape)
# Out:
# (100, 2, 2)
# (99, 2, 2, 1)
# (99, 2, 2)

# %% [markdown]
# Use a context manager to run the ```tf.Session```...

# %%
with tf.Session() as sess:
    init.run()
    #inp = np.expand_dims(series_data[:n_inp_n,:,:],-1)
    #out = np.expand_dims(series_data[n_inp_n,:,:],0)
    inp = np.expand_dims(series_data[:99,:,:],-1)
    out = series_data[1:,:,:]
    print(inp.shape)
    print(out.shape)
    for train_epoch in range(n_epoch):
        #for batch_iter in range(seq_series_data.shape[0]):
        #print(inp.shape, out.shape)
        #print(X_in.get_shape(),Y_pred.get_shape(), Y_true.get_shape(), hf_1.get_shape(), f_1.get_shape(), h_1.get_shape())
        sess.run(loss_min, feed_dict={X: inp, Y_true: out})
        if (train_epoch % 1 == 0):
            y = Y_pred.eval(feed_dict={X: inp})
            #layer_2 = hf_1.eval(feed_dict={X: inp})
            #layer_3 = h_2.eval(feed_dict={X: inp})
            acc_train = loss.eval(feed_dict={X: inp, Y_true: out})
            print(train_epoch, "Batch accuracy (training):", acc_train, "\n", y.shape)#, "\n", layer_2, "\n", layer_3)

    vars = tf.trainable_variables()
    for v in vars:
        print(v)
        print(sess.run(v))
# Out:
# (99, 2, 2, 1)
# (99, 2, 2)
# 0 Batch accuracy (training): 670.5017
#  (99, 2, 2)
# 1 Batch accuracy (training): 668.01526
#  (99, 2, 2)
# 2 Batch accuracy (training): 665.5385
#  (99, 2, 2)
# 3 Batch accuracy (training): 663.0717
#  (99, 2, 2)
# 4 Batch accuracy (training): 660.6148
#  (99, 2, 2)
# 5 Batch accuracy (training): 658.16766
#  (99, 2, 2)
# 6 Batch accuracy (training): 655.7304
#  (99, 2, 2)
# 7 Batch accuracy (training): 653.30273
#  (99, 2, 2)
# 8 Batch accuracy (training): 650.8849
#  (99, 2, 2)
# 9 Batch accuracy (training): 648.4766
#  (99, 2, 2)
# 10 Batch accuracy (training): 646.07806
#  (99, 2, 2)
# 11 Batch accuracy (training): 643.68896
#  (99, 2, 2)
# 12 Batch accuracy (training): 641.3096
#  (99, 2, 2)
# 13 Batch accuracy (training): 638.93964
#  (99, 2, 2)
# 14 Batch accuracy (training): 636.5791
#  (99, 2, 2)
# 15 Batch accuracy (training): 634.228
#  (99, 2, 2)
# 16 Batch accuracy (training): 631.88635
#  (99, 2, 2)
# 17 Batch accuracy (training): 629.5541
#  (99, 2, 2)
# 18 Batch accuracy (training): 627.2311
#  (99, 2, 2)
# 19 Batch accuracy (training): 624.91736
#  (99, 2, 2)
# 20 Batch accuracy (training): 622.61285
#  (99, 2, 2)
# 21 Batch accuracy (training): 620.31757
#  (99, 2, 2)
# 22 Batch accuracy (training): 618.03156
#  (99, 2, 2)
# 23 Batch accuracy (training): 615.75464
#  (99, 2, 2)
# 24 Batch accuracy (training): 613.4867
#  (99, 2, 2)
# 25 Batch accuracy (training): 611.2279
#  (99, 2, 2)
# 26 Batch accuracy (training): 608.9782
#  (99, 2, 2)
# 27 Batch accuracy (training): 606.7373
#  (99, 2, 2)
# 28 Batch accuracy (training): 604.50555
#  (99, 2, 2)
# 29 Batch accuracy (training): 602.28265
#  (99, 2, 2)
# 30 Batch accuracy (training): 600.06866
#  (99, 2, 2)
# 31 Batch accuracy (training): 597.86346
#  (99, 2, 2)
# 32 Batch accuracy (training): 595.6671
#  (99, 2, 2)
# 33 Batch accuracy (training): 593.47955
#  (99, 2, 2)
# 34 Batch accuracy (training): 591.3007
#  (99, 2, 2)
# 35 Batch accuracy (training): 589.1306
#  (99, 2, 2)
# 36 Batch accuracy (training): 586.9692
#  (99, 2, 2)
# 37 Batch accuracy (training): 584.8163
#  (99, 2, 2)
# 38 Batch accuracy (training): 582.6721
#  (99, 2, 2)
# 39 Batch accuracy (training): 580.53644
#  (99, 2, 2)
# 40 Batch accuracy (training): 578.4093
#  (99, 2, 2)
# 41 Batch accuracy (training): 576.2908
#  (99, 2, 2)
# 42 Batch accuracy (training): 574.18054
#  (99, 2, 2)
# 43 Batch accuracy (training): 572.07886
#  (99, 2, 2)
# 44 Batch accuracy (training): 569.9855
#  (99, 2, 2)
# 45 Batch accuracy (training): 567.9006
#  (99, 2, 2)
# 46 Batch accuracy (training): 565.8239
#  (99, 2, 2)
# 47 Batch accuracy (training): 563.7556
#  (99, 2, 2)
# 48 Batch accuracy (training): 561.69556
#  (99, 2, 2)
# 49 Batch accuracy (training): 559.6437
#  (99, 2, 2)
# 50 Batch accuracy (training): 557.60004
#  (99, 2, 2)
# 51 Batch accuracy (training): 555.5646
#  (99, 2, 2)
# 52 Batch accuracy (training): 553.53735
#  (99, 2, 2)
# 53 Batch accuracy (training): 551.51807
#  (99, 2, 2)
# 54 Batch accuracy (training): 549.5069
#  (99, 2, 2)
# 55 Batch accuracy (training): 547.5038
#  (99, 2, 2)
# 56 Batch accuracy (training): 545.50867
#  (99, 2, 2)
# 57 Batch accuracy (training): 543.52155
#  (99, 2, 2)
# 58 Batch accuracy (training): 541.54224
#  (99, 2, 2)
# 59 Batch accuracy (training): 539.57104
#  (99, 2, 2)
# 60 Batch accuracy (training): 537.60767
#  (99, 2, 2)
# 61 Batch accuracy (training): 535.652
#  (99, 2, 2)
# 62 Batch accuracy (training): 533.7043
#  (99, 2, 2)
# 63 Batch accuracy (training): 531.7643
#  (99, 2, 2)
# 64 Batch accuracy (training): 529.8321
#  (99, 2, 2)
# 65 Batch accuracy (training): 527.9076
#  (99, 2, 2)
# 66 Batch accuracy (training): 525.99066
#  (99, 2, 2)
# 67 Batch accuracy (training): 524.0816
#  (99, 2, 2)
# 68 Batch accuracy (training): 522.18005
#  (99, 2, 2)
# 69 Batch accuracy (training): 520.28613
#  (99, 2, 2)
# 70 Batch accuracy (training): 518.3997
#  (99, 2, 2)
# 71 Batch accuracy (training): 516.521
#  (99, 2, 2)
# 72 Batch accuracy (training): 514.64966
#  (99, 2, 2)
# 73 Batch accuracy (training): 512.78577
#  (99, 2, 2)
# 74 Batch accuracy (training): 510.92944
#  (99, 2, 2)
# 75 Batch accuracy (training): 509.0804
#  (99, 2, 2)
# 76 Batch accuracy (training): 507.23892
#  (99, 2, 2)
# 77 Batch accuracy (training): 505.40463
#  (99, 2, 2)
# 78 Batch accuracy (training): 503.57776
#  (99, 2, 2)
# 79 Batch accuracy (training): 501.75812
#  (99, 2, 2)
# 80 Batch accuracy (training): 499.9459
#  (99, 2, 2)
# 81 Batch accuracy (training): 498.14078
#  (99, 2, 2)
# 82 Batch accuracy (training): 496.34293
#  (99, 2, 2)
# 83 Batch accuracy (training): 494.55228
#  (99, 2, 2)
# 84 Batch accuracy (training): 492.7687
#  (99, 2, 2)
# 85 Batch accuracy (training): 490.9923
#  (99, 2, 2)
# 86 Batch accuracy (training): 489.22305
#  (99, 2, 2)
# 87 Batch accuracy (training): 487.46082
#  (99, 2, 2)
# 88 Batch accuracy (training): 485.70566
#  (99, 2, 2)
# 89 Batch accuracy (training): 483.95746
#  (99, 2, 2)
# 90 Batch accuracy (training): 482.21628
#  (99, 2, 2)
# 91 Batch accuracy (training): 480.48206
#  (99, 2, 2)
# 92 Batch accuracy (training): 478.7547
#  (99, 2, 2)
# 93 Batch accuracy (training): 477.03433
#  (99, 2, 2)
# 94 Batch accuracy (training): 475.32074
#  (99, 2, 2)
# 95 Batch accuracy (training): 473.6141
#  (99, 2, 2)
# 96 Batch accuracy (training): 471.91425
#  (99, 2, 2)
# 97 Batch accuracy (training): 470.22128
#  (99, 2, 2)
# 98 Batch accuracy (training): 468.53485
#  (99, 2, 2)
# 99 Batch accuracy (training): 466.85535
#  (99, 2, 2)
# 100 Batch accuracy (training): 465.1825
#  (99, 2, 2)
# 101 Batch accuracy (training): 463.5164
#  (99, 2, 2)
# 102 Batch accuracy (training): 461.8568
#  (99, 2, 2)
# 103 Batch accuracy (training): 460.20398
#  (99, 2, 2)
# 104 Batch accuracy (training): 458.55774
#  (99, 2, 2)
# 105 Batch accuracy (training): 456.91806
#  (99, 2, 2)
# 106 Batch accuracy (training): 455.28485
#  (99, 2, 2)
# 107 Batch accuracy (training): 453.65823
#  (99, 2, 2)
# 108 Batch accuracy (training): 452.03812
#  (99, 2, 2)
# 109 Batch accuracy (training): 450.42447
#  (99, 2, 2)
# 110 Batch accuracy (training): 448.81732
#  (99, 2, 2)
# 111 Batch accuracy (training): 447.21655
#  (99, 2, 2)
# 112 Batch accuracy (training): 445.62213
#  (99, 2, 2)
# 113 Batch accuracy (training): 444.03418
#  (99, 2, 2)
# 114 Batch accuracy (training): 442.45248
#  (99, 2, 2)
# 115 Batch accuracy (training): 440.87714
#  (99, 2, 2)
# 116 Batch accuracy (training): 439.30807
#  (99, 2, 2)
# 117 Batch accuracy (training): 437.7453
#  (99, 2, 2)
# 118 Batch accuracy (training): 436.18884
#  (99, 2, 2)
# 119 Batch accuracy (training): 434.63852
#  (99, 2, 2)
# 120 Batch accuracy (training): 433.09442
#  (99, 2, 2)
# 121 Batch accuracy (training): 431.5565
#  (99, 2, 2)
# 122 Batch accuracy (training): 430.02463
#  (99, 2, 2)
# 123 Batch accuracy (training): 428.49905
#  (99, 2, 2)
# 124 Batch accuracy (training): 426.97943
#  (99, 2, 2)
# 125 Batch accuracy (training): 425.46588
#  (99, 2, 2)
# 126 Batch accuracy (training): 423.95847
#  (99, 2, 2)
# 127 Batch accuracy (training): 422.45706
#  (99, 2, 2)
# 128 Batch accuracy (training): 420.9616
#  (99, 2, 2)
# 129 Batch accuracy (training): 419.47214
#  (99, 2, 2)
# 130 Batch accuracy (training): 417.98868
#  (99, 2, 2)
# 131 Batch accuracy (training): 416.51114
#  (99, 2, 2)
# 132 Batch accuracy (training): 415.03946
#  (99, 2, 2)
# 133 Batch accuracy (training): 413.57358
#  (99, 2, 2)
# 134 Batch accuracy (training): 412.11368
#  (99, 2, 2)
# 135 Batch accuracy (training): 410.6596
#  (99, 2, 2)
# 136 Batch accuracy (training): 409.21133
#  (99, 2, 2)
# 137 Batch accuracy (training): 407.76877
#  (99, 2, 2)
# 138 Batch accuracy (training): 406.33203
#  (99, 2, 2)
# 139 Batch accuracy (training): 404.90103
#  (99, 2, 2)
# 140 Batch accuracy (training): 403.47577
#  (99, 2, 2)
# 141 Batch accuracy (training): 402.05618
#  (99, 2, 2)
# 142 Batch accuracy (training): 400.64227
#  (99, 2, 2)
# 143 Batch accuracy (training): 399.23407
#  (99, 2, 2)
# 144 Batch accuracy (training): 397.8314
#  (99, 2, 2)
# 145 Batch accuracy (training): 396.43436
#  (99, 2, 2)
# 146 Batch accuracy (training): 395.04288
#  (99, 2, 2)
# 147 Batch accuracy (training): 393.65704
#  (99, 2, 2)
# 148 Batch accuracy (training): 392.27667
#  (99, 2, 2)
# 149 Batch accuracy (training): 390.90182
#  (99, 2, 2)
# 150 Batch accuracy (training): 389.5325
#  (99, 2, 2)
# 151 Batch accuracy (training): 388.1686
#  (99, 2, 2)
# 152 Batch accuracy (training): 386.8103
#  (99, 2, 2)
# 153 Batch accuracy (training): 385.45728
#  (99, 2, 2)
# 154 Batch accuracy (training): 384.10965
#  (99, 2, 2)
# 155 Batch accuracy (training): 382.7675
#  (99, 2, 2)
# 156 Batch accuracy (training): 381.4306
#  (99, 2, 2)
# 157 Batch accuracy (training): 380.09915
#  (99, 2, 2)
# 158 Batch accuracy (training): 378.773
#  (99, 2, 2)
# 159 Batch accuracy (training): 377.45215
#  (99, 2, 2)
# 160 Batch accuracy (training): 376.13654
#  (99, 2, 2)
# 161 Batch accuracy (training): 374.8262
#  (99, 2, 2)
# 162 Batch accuracy (training): 373.52106
#  (99, 2, 2)
# 163 Batch accuracy (training): 372.22116
#  (99, 2, 2)
# 164 Batch accuracy (training): 370.92654
#  (99, 2, 2)
# 165 Batch accuracy (training): 369.63696
#  (99, 2, 2)
# 166 Batch accuracy (training): 368.35266
#  (99, 2, 2)
# 167 Batch accuracy (training): 367.0734
#  (99, 2, 2)
# 168 Batch accuracy (training): 365.7993
#  (99, 2, 2)
# 169 Batch accuracy (training): 364.5302
#  (99, 2, 2)
# 170 Batch accuracy (training): 363.2663
#  (99, 2, 2)
# 171 Batch accuracy (training): 362.0074
#  (99, 2, 2)
# 172 Batch accuracy (training): 360.75354
#  (99, 2, 2)
# 173 Batch accuracy (training): 359.5046
#  (99, 2, 2)
# 174 Batch accuracy (training): 358.26077
#  (99, 2, 2)
# 175 Batch accuracy (training): 357.02185
#  (99, 2, 2)
# 176 Batch accuracy (training): 355.78796
#  (99, 2, 2)
# 177 Batch accuracy (training): 354.55896
#  (99, 2, 2)
# 178 Batch accuracy (training): 353.3348
#  (99, 2, 2)
# 179 Batch accuracy (training): 352.11557
#  (99, 2, 2)
# 180 Batch accuracy (training): 350.90125
#  (99, 2, 2)
# 181 Batch accuracy (training): 349.6917
#  (99, 2, 2)
# 182 Batch accuracy (training): 348.48706
#  (99, 2, 2)
# 183 Batch accuracy (training): 347.2872
#  (99, 2, 2)
# 184 Batch accuracy (training): 346.09213
#  (99, 2, 2)
# 185 Batch accuracy (training): 344.90186
#  (99, 2, 2)
# 186 Batch accuracy (training): 343.71637
#  (99, 2, 2)
# 187 Batch accuracy (training): 342.53555
#  (99, 2, 2)
# 188 Batch accuracy (training): 341.35953
#  (99, 2, 2)
# 189 Batch accuracy (training): 340.18817
#  (99, 2, 2)
# 190 Batch accuracy (training): 339.02145
#  (99, 2, 2)
# 191 Batch accuracy (training): 337.8594
#  (99, 2, 2)
# 192 Batch accuracy (training): 336.70203
#  (99, 2, 2)
# 193 Batch accuracy (training): 335.54932
#  (99, 2, 2)
# 194 Batch accuracy (training): 334.40115
#  (99, 2, 2)
# 195 Batch accuracy (training): 333.25757
#  (99, 2, 2)
# 196 Batch accuracy (training): 332.11856
#  (99, 2, 2)
# 197 Batch accuracy (training): 330.98416
#  (99, 2, 2)
# 198 Batch accuracy (training): 329.85425
#  (99, 2, 2)
# 199 Batch accuracy (training): 328.72885
#  (99, 2, 2)
# 200 Batch accuracy (training): 327.608
#  (99, 2, 2)
# 201 Batch accuracy (training): 326.49152
#  (99, 2, 2)
# 202 Batch accuracy (training): 325.37958
#  (99, 2, 2)
# 203 Batch accuracy (training): 324.27206
#  (99, 2, 2)
# 204 Batch accuracy (training): 323.169
#  (99, 2, 2)
# 205 Batch accuracy (training): 322.0703
#  (99, 2, 2)
# 206 Batch accuracy (training): 320.97604
#  (99, 2, 2)
# 207 Batch accuracy (training): 319.88614
#  (99, 2, 2)
# 208 Batch accuracy (training): 318.8006
#  (99, 2, 2)
# 209 Batch accuracy (training): 317.71933
#  (99, 2, 2)
# 210 Batch accuracy (training): 316.64243
#  (99, 2, 2)
# 211 Batch accuracy (training): 315.56985
#  (99, 2, 2)
# 212 Batch accuracy (training): 314.50153
#  (99, 2, 2)
# 213 Batch accuracy (training): 313.43747
#  (99, 2, 2)
# 214 Batch accuracy (training): 312.3777
#  (99, 2, 2)
# 215 Batch accuracy (training): 311.3221
#  (99, 2, 2)
# 216 Batch accuracy (training): 310.27084
#  (99, 2, 2)
# 217 Batch accuracy (training): 309.2237
#  (99, 2, 2)
# 218 Batch accuracy (training): 308.1807
#  (99, 2, 2)
# 219 Batch accuracy (training): 307.14194
#  (99, 2, 2)
# 220 Batch accuracy (training): 306.1073
#  (99, 2, 2)
# 221 Batch accuracy (training): 305.0768
#  (99, 2, 2)
# 222 Batch accuracy (training): 304.0504
#  (99, 2, 2)
# 223 Batch accuracy (training): 303.02817
#  (99, 2, 2)
# 224 Batch accuracy (training): 302.00995
#  (99, 2, 2)
# 225 Batch accuracy (training): 300.99582
#  (99, 2, 2)
# 226 Batch accuracy (training): 299.98575
#  (99, 2, 2)
# 227 Batch accuracy (training): 298.97977
#  (99, 2, 2)
# 228 Batch accuracy (training): 297.97766
#  (99, 2, 2)
# 229 Batch accuracy (training): 296.97968
#  (99, 2, 2)
# 230 Batch accuracy (training): 295.9857
#  (99, 2, 2)
# 231 Batch accuracy (training): 294.9956
#  (99, 2, 2)
# 232 Batch accuracy (training): 294.00946
#  (99, 2, 2)
# 233 Batch accuracy (training): 293.02734
#  (99, 2, 2)
# 234 Batch accuracy (training): 292.04913
#  (99, 2, 2)
# 235 Batch accuracy (training): 291.07474
#  (99, 2, 2)
# 236 Batch accuracy (training): 290.10437
#  (99, 2, 2)
# 237 Batch accuracy (training): 289.13782
#  (99, 2, 2)
# 238 Batch accuracy (training): 288.17514
#  (99, 2, 2)
# 239 Batch accuracy (training): 287.2163
#  (99, 2, 2)
# 240 Batch accuracy (training): 286.2613
#  (99, 2, 2)
# 241 Batch accuracy (training): 285.31006
#  (99, 2, 2)
# 242 Batch accuracy (training): 284.3627
#  (99, 2, 2)
# 243 Batch accuracy (training): 283.41907
#  (99, 2, 2)
# 244 Batch accuracy (training): 282.47928
#  (99, 2, 2)
# 245 Batch accuracy (training): 281.54315
#  (99, 2, 2)
# 246 Batch accuracy (training): 280.61084
#  (99, 2, 2)
# 247 Batch accuracy (training): 279.68222
#  (99, 2, 2)
# 248 Batch accuracy (training): 278.7573
#  (99, 2, 2)
# 249 Batch accuracy (training): 277.8361
#  (99, 2, 2)
# 250 Batch accuracy (training): 276.91855
#  (99, 2, 2)
# 251 Batch accuracy (training): 276.00467
#  (99, 2, 2)
# 252 Batch accuracy (training): 275.0945
#  (99, 2, 2)
# 253 Batch accuracy (training): 274.18793
#  (99, 2, 2)
# 254 Batch accuracy (training): 273.285
#  (99, 2, 2)
# 255 Batch accuracy (training): 272.38565
#  (99, 2, 2)
# 256 Batch accuracy (training): 271.48993
#  (99, 2, 2)
# 257 Batch accuracy (training): 270.59772
#  (99, 2, 2)
# 258 Batch accuracy (training): 269.70914
#  (99, 2, 2)
# 259 Batch accuracy (training): 268.82407
#  (99, 2, 2)
# 260 Batch accuracy (training): 267.94257
#  (99, 2, 2)
# 261 Batch accuracy (training): 267.0646
#  (99, 2, 2)
# 262 Batch accuracy (training): 266.19006
#  (99, 2, 2)
# 263 Batch accuracy (training): 265.3191
#  (99, 2, 2)
# 264 Batch accuracy (training): 264.4516
#  (99, 2, 2)
# 265 Batch accuracy (training): 263.58755
#  (99, 2, 2)
# 266 Batch accuracy (training): 262.727
#  (99, 2, 2)
# 267 Batch accuracy (training): 261.86984
#  (99, 2, 2)
# 268 Batch accuracy (training): 261.0161
#  (99, 2, 2)
# 269 Batch accuracy (training): 260.16577
#  (99, 2, 2)
# 270 Batch accuracy (training): 259.31885
#  (99, 2, 2)
# 271 Batch accuracy (training): 258.4753
#  (99, 2, 2)
# 272 Batch accuracy (training): 257.63516
#  (99, 2, 2)
# 273 Batch accuracy (training): 256.79834
#  (99, 2, 2)
# 274 Batch accuracy (training): 255.96492
#  (99, 2, 2)
# 275 Batch accuracy (training): 255.13477
#  (99, 2, 2)
# 276 Batch accuracy (training): 254.30794
#  (99, 2, 2)
# 277 Batch accuracy (training): 253.48445
#  (99, 2, 2)
# 278 Batch accuracy (training): 252.66422
#  (99, 2, 2)
# 279 Batch accuracy (training): 251.8473
#  (99, 2, 2)
# 280 Batch accuracy (training): 251.03362
#  (99, 2, 2)
# 281 Batch accuracy (training): 250.22318
#  (99, 2, 2)
# 282 Batch accuracy (training): 249.416
#  (99, 2, 2)
# 283 Batch accuracy (training): 248.61205
#  (99, 2, 2)
# 284 Batch accuracy (training): 247.81126
#  (99, 2, 2)
# 285 Batch accuracy (training): 247.01373
#  (99, 2, 2)
# 286 Batch accuracy (training): 246.21935
#  (99, 2, 2)
# 287 Batch accuracy (training): 245.42819
#  (99, 2, 2)
# 288 Batch accuracy (training): 244.6402
#  (99, 2, 2)
# 289 Batch accuracy (training): 243.85532
#  (99, 2, 2)
# 290 Batch accuracy (training): 243.07356
#  (99, 2, 2)
# 291 Batch accuracy (training): 242.2949
#  (99, 2, 2)
# 292 Batch accuracy (training): 241.51945
#  (99, 2, 2)
# 293 Batch accuracy (training): 240.747
#  (99, 2, 2)
# 294 Batch accuracy (training): 239.9777
#  (99, 2, 2)
# 295 Batch accuracy (training): 239.21149
#  (99, 2, 2)
# 296 Batch accuracy (training): 238.44827
#  (99, 2, 2)
# 297 Batch accuracy (training): 237.68813
#  (99, 2, 2)
# 298 Batch accuracy (training): 236.93108
#  (99, 2, 2)
# 299 Batch accuracy (training): 236.17699
#  (99, 2, 2)
# 300 Batch accuracy (training): 235.4259
#  (99, 2, 2)
# 301 Batch accuracy (training): 234.67787
#  (99, 2, 2)
# 302 Batch accuracy (training): 233.93279
#  (99, 2, 2)
# 303 Batch accuracy (training): 233.19067
#  (99, 2, 2)
# 304 Batch accuracy (training): 232.4516
#  (99, 2, 2)
# 305 Batch accuracy (training): 231.71545
#  (99, 2, 2)
# 306 Batch accuracy (training): 230.98218
#  (99, 2, 2)
# 307 Batch accuracy (training): 230.25189
#  (99, 2, 2)
# 308 Batch accuracy (training): 229.52449
#  (99, 2, 2)
# 309 Batch accuracy (training): 228.80003
#  (99, 2, 2)
# 310 Batch accuracy (training): 228.07846
#  (99, 2, 2)
# 311 Batch accuracy (training): 227.35976
#  (99, 2, 2)
# 312 Batch accuracy (training): 226.64394
#  (99, 2, 2)
# 313 Batch accuracy (training): 225.93092
#  (99, 2, 2)
# 314 Batch accuracy (training): 225.22084
#  (99, 2, 2)
# 315 Batch accuracy (training): 224.51358
#  (99, 2, 2)
# 316 Batch accuracy (training): 223.80914
#  (99, 2, 2)
# 317 Batch accuracy (training): 223.10751
#  (99, 2, 2)
# 318 Batch accuracy (training): 222.40866
#  (99, 2, 2)
# 319 Batch accuracy (training): 221.71263
#  (99, 2, 2)
# 320 Batch accuracy (training): 221.01938
#  (99, 2, 2)
# 321 Batch accuracy (training): 220.32887
#  (99, 2, 2)
# 322 Batch accuracy (training): 219.64116
#  (99, 2, 2)
# 323 Batch accuracy (training): 218.95616
#  (99, 2, 2)
# 324 Batch accuracy (training): 218.27393
#  (99, 2, 2)
# 325 Batch accuracy (training): 217.5944
#  (99, 2, 2)
# 326 Batch accuracy (training): 216.91759
#  (99, 2, 2)
# 327 Batch accuracy (training): 216.24353
#  (99, 2, 2)
# 328 Batch accuracy (training): 215.57213
#  (99, 2, 2)
# 329 Batch accuracy (training): 214.90337
#  (99, 2, 2)
# 330 Batch accuracy (training): 214.23734
#  (99, 2, 2)
# 331 Batch accuracy (training): 213.57394
#  (99, 2, 2)
# 332 Batch accuracy (training): 212.91321
#  (99, 2, 2)
# 333 Batch accuracy (training): 212.25517
#  (99, 2, 2)
# 334 Batch accuracy (training): 211.59967
#  (99, 2, 2)
# 335 Batch accuracy (training): 210.94681
#  (99, 2, 2)
# 336 Batch accuracy (training): 210.2966
#  (99, 2, 2)
# 337 Batch accuracy (training): 209.64896
#  (99, 2, 2)
# 338 Batch accuracy (training): 209.0039
#  (99, 2, 2)
# 339 Batch accuracy (training): 208.36142
#  (99, 2, 2)
# 340 Batch accuracy (training): 207.72151
#  (99, 2, 2)
# 341 Batch accuracy (training): 207.08418
#  (99, 2, 2)
# 342 Batch accuracy (training): 206.44937
#  (99, 2, 2)
# 343 Batch accuracy (training): 205.81712
#  (99, 2, 2)
# 344 Batch accuracy (training): 205.18735
#  (99, 2, 2)
# 345 Batch accuracy (training): 204.56015
#  (99, 2, 2)
# 346 Batch accuracy (training): 203.93541
#  (99, 2, 2)
# 347 Batch accuracy (training): 203.31319
#  (99, 2, 2)
# 348 Batch accuracy (training): 202.69344
#  (99, 2, 2)
# 349 Batch accuracy (training): 202.07622
#  (99, 2, 2)
# 350 Batch accuracy (training): 201.4614
#  (99, 2, 2)
# 351 Batch accuracy (training): 200.84908
#  (99, 2, 2)
# 352 Batch accuracy (training): 200.23917
#  (99, 2, 2)
# 353 Batch accuracy (training): 199.63173
#  (99, 2, 2)
# 354 Batch accuracy (training): 199.02673
#  (99, 2, 2)
# 355 Batch accuracy (training): 198.42412
#  (99, 2, 2)
# 356 Batch accuracy (training): 197.8239
#  (99, 2, 2)
# 357 Batch accuracy (training): 197.22614
#  (99, 2, 2)
# 358 Batch accuracy (training): 196.63072
#  (99, 2, 2)
# 359 Batch accuracy (training): 196.03767
#  (99, 2, 2)
# 360 Batch accuracy (training): 195.447
#  (99, 2, 2)
# 361 Batch accuracy (training): 194.85872
#  (99, 2, 2)
# 362 Batch accuracy (training): 194.27278
#  (99, 2, 2)
# 363 Batch accuracy (training): 193.68918
#  (99, 2, 2)
# 364 Batch accuracy (training): 193.1079
#  (99, 2, 2)
# 365 Batch accuracy (training): 192.52892
#  (99, 2, 2)
# 366 Batch accuracy (training): 191.9523
#  (99, 2, 2)
# 367 Batch accuracy (training): 191.37798
#  (99, 2, 2)
# 368 Batch accuracy (training): 190.80592
#  (99, 2, 2)
# 369 Batch accuracy (training): 190.23619
#  (99, 2, 2)
# 370 Batch accuracy (training): 189.66869
#  (99, 2, 2)
# 371 Batch accuracy (training): 189.1035
#  (99, 2, 2)
# 372 Batch accuracy (training): 188.54053
#  (99, 2, 2)
# 373 Batch accuracy (training): 187.97986
#  (99, 2, 2)
# 374 Batch accuracy (training): 187.42139
#  (99, 2, 2)
# 375 Batch accuracy (training): 186.86514
#  (99, 2, 2)
# 376 Batch accuracy (training): 186.31114
#  (99, 2, 2)
# 377 Batch accuracy (training): 185.75935
#  (99, 2, 2)
# 378 Batch accuracy (training): 185.20973
#  (99, 2, 2)
# 379 Batch accuracy (training): 184.66235
#  (99, 2, 2)
# 380 Batch accuracy (training): 184.11714
#  (99, 2, 2)
# 381 Batch accuracy (training): 183.57413
#  (99, 2, 2)
# 382 Batch accuracy (training): 183.03328
#  (99, 2, 2)
# 383 Batch accuracy (training): 182.49455
#  (99, 2, 2)
# 384 Batch accuracy (training): 181.95802
#  (99, 2, 2)
# 385 Batch accuracy (training): 181.42365
#  (99, 2, 2)
# 386 Batch accuracy (training): 180.89136
#  (99, 2, 2)
# 387 Batch accuracy (training): 180.36125
#  (99, 2, 2)
# 388 Batch accuracy (training): 179.83324
#  (99, 2, 2)
# 389 Batch accuracy (training): 179.30731
#  (99, 2, 2)
# 390 Batch accuracy (training): 178.78352
#  (99, 2, 2)
# 391 Batch accuracy (training): 178.26181
#  (99, 2, 2)
# 392 Batch accuracy (training): 177.74214
#  (99, 2, 2)
# 393 Batch accuracy (training): 177.22462
#  (99, 2, 2)
# 394 Batch accuracy (training): 176.70917
#  (99, 2, 2)
# 395 Batch accuracy (training): 176.19571
#  (99, 2, 2)
# 396 Batch accuracy (training): 175.68434
#  (99, 2, 2)
# 397 Batch accuracy (training): 175.17502
#  (99, 2, 2)
# 398 Batch accuracy (training): 174.66771
#  (99, 2, 2)
# 399 Batch accuracy (training): 174.16245
#  (99, 2, 2)
# 400 Batch accuracy (training): 173.6592
#  (99, 2, 2)
# 401 Batch accuracy (training): 173.15796
#  (99, 2, 2)
# 402 Batch accuracy (training): 172.65872
#  (99, 2, 2)
# 403 Batch accuracy (training): 172.1615
#  (99, 2, 2)
# 404 Batch accuracy (training): 171.66623
#  (99, 2, 2)
# 405 Batch accuracy (training): 171.17296
#  (99, 2, 2)
# 406 Batch accuracy (training): 170.68169
#  (99, 2, 2)
# 407 Batch accuracy (training): 170.19234
#  (99, 2, 2)
# 408 Batch accuracy (training): 169.70499
#  (99, 2, 2)
# 409 Batch accuracy (training): 169.21951
#  (99, 2, 2)
# 410 Batch accuracy (training): 168.73601
#  (99, 2, 2)
# 411 Batch accuracy (training): 168.25446
#  (99, 2, 2)
# 412 Batch accuracy (training): 167.77483
#  (99, 2, 2)
# 413 Batch accuracy (training): 167.29709
#  (99, 2, 2)
# 414 Batch accuracy (training): 166.82127
#  (99, 2, 2)
# 415 Batch accuracy (training): 166.34738
#  (99, 2, 2)
# 416 Batch accuracy (training): 165.87535
#  (99, 2, 2)
# 417 Batch accuracy (training): 165.40524
#  (99, 2, 2)
# 418 Batch accuracy (training): 164.93697
#  (99, 2, 2)
# 419 Batch accuracy (training): 164.47058
#  (99, 2, 2)
# 420 Batch accuracy (training): 164.00604
#  (99, 2, 2)
# 421 Batch accuracy (training): 163.54341
#  (99, 2, 2)
# 422 Batch accuracy (training): 163.08258
#  (99, 2, 2)
# 423 Batch accuracy (training): 162.62363
#  (99, 2, 2)
# 424 Batch accuracy (training): 162.16649
#  (99, 2, 2)
# 425 Batch accuracy (training): 161.71118
#  (99, 2, 2)
# 426 Batch accuracy (training): 161.25769
#  (99, 2, 2)
# 427 Batch accuracy (training): 160.80598
#  (99, 2, 2)
# 428 Batch accuracy (training): 160.35614
#  (99, 2, 2)
# 429 Batch accuracy (training): 159.90805
#  (99, 2, 2)
# 430 Batch accuracy (training): 159.46178
#  (99, 2, 2)
# 431 Batch accuracy (training): 159.01726
#  (99, 2, 2)
# 432 Batch accuracy (training): 158.57454
#  (99, 2, 2)
# 433 Batch accuracy (training): 158.13358
#  (99, 2, 2)
# 434 Batch accuracy (training): 157.69438
#  (99, 2, 2)
# 435 Batch accuracy (training): 157.25691
#  (99, 2, 2)
# 436 Batch accuracy (training): 156.82126
#  (99, 2, 2)
# 437 Batch accuracy (training): 156.3873
#  (99, 2, 2)
# 438 Batch accuracy (training): 155.95508
#  (99, 2, 2)
# 439 Batch accuracy (training): 155.5246
#  (99, 2, 2)
# 440 Batch accuracy (training): 155.09583
#  (99, 2, 2)
# 441 Batch accuracy (training): 154.66876
#  (99, 2, 2)
# 442 Batch accuracy (training): 154.24342
#  (99, 2, 2)
# 443 Batch accuracy (training): 153.81975
#  (99, 2, 2)
# 444 Batch accuracy (training): 153.39783
#  (99, 2, 2)
# 445 Batch accuracy (training): 152.97752
#  (99, 2, 2)
# 446 Batch accuracy (training): 152.55894
#  (99, 2, 2)
# 447 Batch accuracy (training): 152.14203
#  (99, 2, 2)
# 448 Batch accuracy (training): 151.72676
#  (99, 2, 2)
# 449 Batch accuracy (training): 151.31316
#  (99, 2, 2)
# 450 Batch accuracy (training): 150.90123
#  (99, 2, 2)
# 451 Batch accuracy (training): 150.49095
#  (99, 2, 2)
# 452 Batch accuracy (training): 150.08229
#  (99, 2, 2)
# 453 Batch accuracy (training): 149.67525
#  (99, 2, 2)
# 454 Batch accuracy (training): 149.26985
#  (99, 2, 2)
# 455 Batch accuracy (training): 148.86609
#  (99, 2, 2)
# 456 Batch accuracy (training): 148.46391
#  (99, 2, 2)
# 457 Batch accuracy (training): 148.06335
#  (99, 2, 2)
# 458 Batch accuracy (training): 147.66444
#  (99, 2, 2)
# 459 Batch accuracy (training): 147.26706
#  (99, 2, 2)
# 460 Batch accuracy (training): 146.87128
#  (99, 2, 2)
# 461 Batch accuracy (training): 146.4771
#  (99, 2, 2)
# 462 Batch accuracy (training): 146.08449
#  (99, 2, 2)
# 463 Batch accuracy (training): 145.69344
#  (99, 2, 2)
# 464 Batch accuracy (training): 145.30394
#  (99, 2, 2)
# 465 Batch accuracy (training): 144.916
#  (99, 2, 2)
# 466 Batch accuracy (training): 144.52963
#  (99, 2, 2)
# 467 Batch accuracy (training): 144.14479
#  (99, 2, 2)
# 468 Batch accuracy (training): 143.7615
#  (99, 2, 2)
# 469 Batch accuracy (training): 143.37973
#  (99, 2, 2)
# 470 Batch accuracy (training): 142.99951
#  (99, 2, 2)
# 471 Batch accuracy (training): 142.62077
#  (99, 2, 2)
# 472 Batch accuracy (training): 142.24358
#  (99, 2, 2)
# 473 Batch accuracy (training): 141.86787
#  (99, 2, 2)
# 474 Batch accuracy (training): 141.49365
#  (99, 2, 2)
# 475 Batch accuracy (training): 141.12097
#  (99, 2, 2)
# 476 Batch accuracy (training): 140.74974
#  (99, 2, 2)
# 477 Batch accuracy (training): 140.38
#  (99, 2, 2)
# 478 Batch accuracy (training): 140.01176
#  (99, 2, 2)
# 479 Batch accuracy (training): 139.64496
#  (99, 2, 2)
# 480 Batch accuracy (training): 139.27968
#  (99, 2, 2)
# 481 Batch accuracy (training): 138.91582
#  (99, 2, 2)
# 482 Batch accuracy (training): 138.55344
#  (99, 2, 2)
# 483 Batch accuracy (training): 138.19247
#  (99, 2, 2)
# 484 Batch accuracy (training): 137.83296
#  (99, 2, 2)
# 485 Batch accuracy (training): 137.47487
#  (99, 2, 2)
# 486 Batch accuracy (training): 137.11826
#  (99, 2, 2)
# 487 Batch accuracy (training): 136.76302
#  (99, 2, 2)
# 488 Batch accuracy (training): 136.4092
#  (99, 2, 2)
# 489 Batch accuracy (training): 136.05684
#  (99, 2, 2)
# 490 Batch accuracy (training): 135.70584
#  (99, 2, 2)
# 491 Batch accuracy (training): 135.35628
#  (99, 2, 2)
# 492 Batch accuracy (training): 135.00813
#  (99, 2, 2)
# 493 Batch accuracy (training): 134.66132
#  (99, 2, 2)
# 494 Batch accuracy (training): 134.31592
#  (99, 2, 2)
# 495 Batch accuracy (training): 133.97191
#  (99, 2, 2)
# 496 Batch accuracy (training): 133.62926
#  (99, 2, 2)
# 497 Batch accuracy (training): 133.288
#  (99, 2, 2)
# 498 Batch accuracy (training): 132.94807
#  (99, 2, 2)
# 499 Batch accuracy (training): 132.60951
#  (99, 2, 2)
# 500 Batch accuracy (training): 132.27231
#  (99, 2, 2)
# 501 Batch accuracy (training): 131.93646
#  (99, 2, 2)
# 502 Batch accuracy (training): 131.60194
#  (99, 2, 2)
# 503 Batch accuracy (training): 131.26877
#  (99, 2, 2)
# 504 Batch accuracy (training): 130.93694
#  (99, 2, 2)
# 505 Batch accuracy (training): 130.6064
#  (99, 2, 2)
# 506 Batch accuracy (training): 130.27722
#  (99, 2, 2)
# 507 Batch accuracy (training): 129.94934
#  (99, 2, 2)
# 508 Batch accuracy (training): 129.62274
#  (99, 2, 2)
# 509 Batch accuracy (training): 129.2975
#  (99, 2, 2)
# 510 Batch accuracy (training): 128.97353
#  (99, 2, 2)
# 511 Batch accuracy (training): 128.65085
#  (99, 2, 2)
# 512 Batch accuracy (training): 128.32945
#  (99, 2, 2)
# 513 Batch accuracy (training): 128.00938
#  (99, 2, 2)
# 514 Batch accuracy (training): 127.69053
#  (99, 2, 2)
# 515 Batch accuracy (training): 127.37301
#  (99, 2, 2)
# 516 Batch accuracy (training): 127.05673
#  (99, 2, 2)
# 517 Batch accuracy (training): 126.74171
#  (99, 2, 2)
# 518 Batch accuracy (training): 126.42795
#  (99, 2, 2)
# 519 Batch accuracy (training): 126.11546
#  (99, 2, 2)
# 520 Batch accuracy (training): 125.80422
#  (99, 2, 2)
# 521 Batch accuracy (training): 125.4942
#  (99, 2, 2)
# 522 Batch accuracy (training): 125.18544
#  (99, 2, 2)
# 523 Batch accuracy (training): 124.8779
#  (99, 2, 2)
# 524 Batch accuracy (training): 124.57156
#  (99, 2, 2)
# 525 Batch accuracy (training): 124.2665
#  (99, 2, 2)
# 526 Batch accuracy (training): 123.96266
#  (99, 2, 2)
# 527 Batch accuracy (training): 123.66001
#  (99, 2, 2)
# 528 Batch accuracy (training): 123.35857
#  (99, 2, 2)
# 529 Batch accuracy (training): 123.05833
#  (99, 2, 2)
# 530 Batch accuracy (training): 122.7593
#  (99, 2, 2)
# 531 Batch accuracy (training): 122.46145
#  (99, 2, 2)
# 532 Batch accuracy (training): 122.16481
#  (99, 2, 2)
# 533 Batch accuracy (training): 121.86933
#  (99, 2, 2)
# 534 Batch accuracy (training): 121.57507
#  (99, 2, 2)
# 535 Batch accuracy (training): 121.28195
#  (99, 2, 2)
# 536 Batch accuracy (training): 120.99002
#  (99, 2, 2)
# 537 Batch accuracy (training): 120.69926
#  (99, 2, 2)
# 538 Batch accuracy (training): 120.40963
#  (99, 2, 2)
# 539 Batch accuracy (training): 120.12117
#  (99, 2, 2)
# 540 Batch accuracy (training): 119.83388
#  (99, 2, 2)
# 541 Batch accuracy (training): 119.54773
#  (99, 2, 2)
# 542 Batch accuracy (training): 119.262726
#  (99, 2, 2)
# 543 Batch accuracy (training): 118.978874
#  (99, 2, 2)
# 544 Batch accuracy (training): 118.69611
#  (99, 2, 2)
# 545 Batch accuracy (training): 118.41451
#  (99, 2, 2)
# 546 Batch accuracy (training): 118.13403
#  (99, 2, 2)
# 547 Batch accuracy (training): 117.854706
#  (99, 2, 2)
# 548 Batch accuracy (training): 117.57645
#  (99, 2, 2)
# 549 Batch accuracy (training): 117.29933
#  (99, 2, 2)
# 550 Batch accuracy (training): 117.0233
#  (99, 2, 2)
# 551 Batch accuracy (training): 116.74836
#  (99, 2, 2)
# 552 Batch accuracy (training): 116.47454
#  (99, 2, 2)
# 553 Batch accuracy (training): 116.20184
#  (99, 2, 2)
# 554 Batch accuracy (training): 115.93018
#  (99, 2, 2)
# 555 Batch accuracy (training): 115.65963
#  (99, 2, 2)
# 556 Batch accuracy (training): 115.39019
#  (99, 2, 2)
# 557 Batch accuracy (training): 115.12177
#  (99, 2, 2)
# 558 Batch accuracy (training): 114.85447
#  (99, 2, 2)
# 559 Batch accuracy (training): 114.588196
#  (99, 2, 2)
# 560 Batch accuracy (training): 114.32301
#  (99, 2, 2)
# 561 Batch accuracy (training): 114.058876
#  (99, 2, 2)
# 562 Batch accuracy (training): 113.79581
#  (99, 2, 2)
# 563 Batch accuracy (training): 113.533775
#  (99, 2, 2)
# 564 Batch accuracy (training): 113.27284
#  (99, 2, 2)
# 565 Batch accuracy (training): 113.01287
#  (99, 2, 2)
# 566 Batch accuracy (training): 112.75398
#  (99, 2, 2)
# 567 Batch accuracy (training): 112.49613
#  (99, 2, 2)
# 568 Batch accuracy (training): 112.23932
#  (99, 2, 2)
# 569 Batch accuracy (training): 111.9835
#  (99, 2, 2)
# 570 Batch accuracy (training): 111.728714
#  (99, 2, 2)
# 571 Batch accuracy (training): 111.474945
#  (99, 2, 2)
# 572 Batch accuracy (training): 111.22221
#  (99, 2, 2)
# 573 Batch accuracy (training): 110.970474
#  (99, 2, 2)
# 574 Batch accuracy (training): 110.719734
#  (99, 2, 2)
# 575 Batch accuracy (training): 110.470024
#  (99, 2, 2)
# 576 Batch accuracy (training): 110.221275
#  (99, 2, 2)
# 577 Batch accuracy (training): 109.97354
#  (99, 2, 2)
# 578 Batch accuracy (training): 109.72679
#  (99, 2, 2)
# 579 Batch accuracy (training): 109.48104
#  (99, 2, 2)
# 580 Batch accuracy (training): 109.23625
#  (99, 2, 2)
# 581 Batch accuracy (training): 108.992455
#  (99, 2, 2)
# 582 Batch accuracy (training): 108.74964
#  (99, 2, 2)
# 583 Batch accuracy (training): 108.50777
#  (99, 2, 2)
# 584 Batch accuracy (training): 108.266884
#  (99, 2, 2)
# 585 Batch accuracy (training): 108.02697
#  (99, 2, 2)
# 586 Batch accuracy (training): 107.787994
#  (99, 2, 2)
# 587 Batch accuracy (training): 107.549965
#  (99, 2, 2)
# 588 Batch accuracy (training): 107.31291
#  (99, 2, 2)
# 589 Batch accuracy (training): 107.076775
#  (99, 2, 2)
# 590 Batch accuracy (training): 106.841606
#  (99, 2, 2)
# 591 Batch accuracy (training): 106.60738
#  (99, 2, 2)
# 592 Batch accuracy (training): 106.37407
#  (99, 2, 2)
# 593 Batch accuracy (training): 106.14172
#  (99, 2, 2)
# 594 Batch accuracy (training): 105.91028
#  (99, 2, 2)
# 595 Batch accuracy (training): 105.67976
#  (99, 2, 2)
# 596 Batch accuracy (training): 105.45017
#  (99, 2, 2)
# 597 Batch accuracy (training): 105.22151
#  (99, 2, 2)
# 598 Batch accuracy (training): 104.993744
#  (99, 2, 2)
# 599 Batch accuracy (training): 104.7669
#  (99, 2, 2)
# 600 Batch accuracy (training): 104.540955
#  (99, 2, 2)
# 601 Batch accuracy (training): 104.315926
#  (99, 2, 2)
# 602 Batch accuracy (training): 104.091774
#  (99, 2, 2)
# 603 Batch accuracy (training): 103.868546
#  (99, 2, 2)
# 604 Batch accuracy (training): 103.64619
#  (99, 2, 2)
# 605 Batch accuracy (training): 103.42473
#  (99, 2, 2)
# 606 Batch accuracy (training): 103.20414
#  (99, 2, 2)
# 607 Batch accuracy (training): 102.98444
#  (99, 2, 2)
# 608 Batch accuracy (training): 102.76563
#  (99, 2, 2)
# 609 Batch accuracy (training): 102.54768
#  (99, 2, 2)
# 610 Batch accuracy (training): 102.33059
#  (99, 2, 2)
# 611 Batch accuracy (training): 102.11439
#  (99, 2, 2)
# 612 Batch accuracy (training): 101.89905
#  (99, 2, 2)
# 613 Batch accuracy (training): 101.68459
#  (99, 2, 2)
# 614 Batch accuracy (training): 101.47095
#  (99, 2, 2)
# 615 Batch accuracy (training): 101.258156
#  (99, 2, 2)
# 616 Batch accuracy (training): 101.04624
#  (99, 2, 2)
# 617 Batch accuracy (training): 100.83517
#  (99, 2, 2)
# 618 Batch accuracy (training): 100.62496
#  (99, 2, 2)
# 619 Batch accuracy (training): 100.41554
#  (99, 2, 2)
# 620 Batch accuracy (training): 100.207
#  (99, 2, 2)
# 621 Batch accuracy (training): 99.99928
#  (99, 2, 2)
# 622 Batch accuracy (training): 99.7924
#  (99, 2, 2)
# 623 Batch accuracy (training): 99.58632
#  (99, 2, 2)
# 624 Batch accuracy (training): 99.38107
#  (99, 2, 2)
# 625 Batch accuracy (training): 99.176636
#  (99, 2, 2)
# 626 Batch accuracy (training): 98.97306
#  (99, 2, 2)
# 627 Batch accuracy (training): 98.77028
#  (99, 2, 2)
# 628 Batch accuracy (training): 98.5683
#  (99, 2, 2)
# 629 Batch accuracy (training): 98.36713
#  (99, 2, 2)
# 630 Batch accuracy (training): 98.16676
#  (99, 2, 2)
# 631 Batch accuracy (training): 97.96716
#  (99, 2, 2)
# 632 Batch accuracy (training): 97.76841
#  (99, 2, 2)
# 633 Batch accuracy (training): 97.57042
#  (99, 2, 2)
# 634 Batch accuracy (training): 97.37326
#  (99, 2, 2)
# 635 Batch accuracy (training): 97.176834
#  (99, 2, 2)
# 636 Batch accuracy (training): 96.98124
#  (99, 2, 2)
# 637 Batch accuracy (training): 96.7864
#  (99, 2, 2)
# 638 Batch accuracy (training): 96.59235
#  (99, 2, 2)
# 639 Batch accuracy (training): 96.399086
#  (99, 2, 2)
# 640 Batch accuracy (training): 96.20659
#  (99, 2, 2)
# 641 Batch accuracy (training): 96.014824
#  (99, 2, 2)
# 642 Batch accuracy (training): 95.82385
#  (99, 2, 2)
# 643 Batch accuracy (training): 95.63365
#  (99, 2, 2)
# 644 Batch accuracy (training): 95.444214
#  (99, 2, 2)
# 645 Batch accuracy (training): 95.25552
#  (99, 2, 2)
# 646 Batch accuracy (training): 95.0676
#  (99, 2, 2)
# 647 Batch accuracy (training): 94.88041
#  (99, 2, 2)
# 648 Batch accuracy (training): 94.69398
#  (99, 2, 2)
# 649 Batch accuracy (training): 94.508286
#  (99, 2, 2)
# 650 Batch accuracy (training): 94.32332
#  (99, 2, 2)
# 651 Batch accuracy (training): 94.13912
#  (99, 2, 2)
# 652 Batch accuracy (training): 93.95566
#  (99, 2, 2)
# 653 Batch accuracy (training): 93.7729
#  (99, 2, 2)
# 654 Batch accuracy (training): 93.5909
#  (99, 2, 2)
# 655 Batch accuracy (training): 93.40961
#  (99, 2, 2)
# 656 Batch accuracy (training): 93.229065
#  (99, 2, 2)
# 657 Batch accuracy (training): 93.04921
#  (99, 2, 2)
# 658 Batch accuracy (training): 92.87011
#  (99, 2, 2)
# 659 Batch accuracy (training): 92.6917
#  (99, 2, 2)
# 660 Batch accuracy (training): 92.514
#  (99, 2, 2)
# 661 Batch accuracy (training): 92.337036
#  (99, 2, 2)
# 662 Batch accuracy (training): 92.16077
#  (99, 2, 2)
# 663 Batch accuracy (training): 91.985176
#  (99, 2, 2)
# 664 Batch accuracy (training): 91.81032
#  (99, 2, 2)
# 665 Batch accuracy (training): 91.63615
#  (99, 2, 2)
# 666 Batch accuracy (training): 91.46266
#  (99, 2, 2)
# 667 Batch accuracy (training): 91.28991
#  (99, 2, 2)
# 668 Batch accuracy (training): 91.117805
#  (99, 2, 2)
# 669 Batch accuracy (training): 90.94641
#  (99, 2, 2)
# 670 Batch accuracy (training): 90.775696
#  (99, 2, 2)
# 671 Batch accuracy (training): 90.60566
#  (99, 2, 2)
# 672 Batch accuracy (training): 90.43631
#  (99, 2, 2)
# 673 Batch accuracy (training): 90.267624
#  (99, 2, 2)
# 674 Batch accuracy (training): 90.09962
#  (99, 2, 2)
# 675 Batch accuracy (training): 89.932304
#  (99, 2, 2)
# 676 Batch accuracy (training): 89.765625
#  (99, 2, 2)
# 677 Batch accuracy (training): 89.59965
#  (99, 2, 2)
# 678 Batch accuracy (training): 89.4343
#  (99, 2, 2)
# 679 Batch accuracy (training): 89.26963
#  (99, 2, 2)
# 680 Batch accuracy (training): 89.10561
#  (99, 2, 2)
# 681 Batch accuracy (training): 88.942245
#  (99, 2, 2)
# 682 Batch accuracy (training): 88.77953
#  (99, 2, 2)
# 683 Batch accuracy (training): 88.617485
#  (99, 2, 2)
# 684 Batch accuracy (training): 88.45609
#  (99, 2, 2)
# 685 Batch accuracy (training): 88.29533
#  (99, 2, 2)
# 686 Batch accuracy (training): 88.1352
#  (99, 2, 2)
# 687 Batch accuracy (training): 87.975716
#  (99, 2, 2)
# 688 Batch accuracy (training): 87.81688
#  (99, 2, 2)
# 689 Batch accuracy (training): 87.65867
#  (99, 2, 2)
# 690 Batch accuracy (training): 87.501076
#  (99, 2, 2)
# 691 Batch accuracy (training): 87.34413
#  (99, 2, 2)
# 692 Batch accuracy (training): 87.187805
#  (99, 2, 2)
# 693 Batch accuracy (training): 87.03212
#  (99, 2, 2)
# 694 Batch accuracy (training): 86.877045
#  (99, 2, 2)
# 695 Batch accuracy (training): 86.72259
#  (99, 2, 2)
# 696 Batch accuracy (training): 86.568756
#  (99, 2, 2)
# 697 Batch accuracy (training): 86.415535
#  (99, 2, 2)
# 698 Batch accuracy (training): 86.2629
#  (99, 2, 2)
# 699 Batch accuracy (training): 86.1109
#  (99, 2, 2)
# 700 Batch accuracy (training): 85.95952
#  (99, 2, 2)
# 701 Batch accuracy (training): 85.80873
#  (99, 2, 2)
# 702 Batch accuracy (training): 85.65856
#  (99, 2, 2)
# 703 Batch accuracy (training): 85.50896
#  (99, 2, 2)
# 704 Batch accuracy (training): 85.35997
#  (99, 2, 2)
# 705 Batch accuracy (training): 85.21157
#  (99, 2, 2)
# 706 Batch accuracy (training): 85.063774
#  (99, 2, 2)
# 707 Batch accuracy (training): 84.916565
#  (99, 2, 2)
# 708 Batch accuracy (training): 84.76994
#  (99, 2, 2)
# 709 Batch accuracy (training): 84.623924
#  (99, 2, 2)
# 710 Batch accuracy (training): 84.47847
#  (99, 2, 2)
# 711 Batch accuracy (training): 84.33361
#  (99, 2, 2)
# 712 Batch accuracy (training): 84.189316
#  (99, 2, 2)
# 713 Batch accuracy (training): 84.045586
#  (99, 2, 2)
# 714 Batch accuracy (training): 83.902466
#  (99, 2, 2)
# 715 Batch accuracy (training): 83.75989
#  (99, 2, 2)
# 716 Batch accuracy (training): 83.6179
#  (99, 2, 2)
# 717 Batch accuracy (training): 83.47644
#  (99, 2, 2)
# 718 Batch accuracy (training): 83.3356
#  (99, 2, 2)
# 719 Batch accuracy (training): 83.195274
#  (99, 2, 2)
# 720 Batch accuracy (training): 83.05556
#  (99, 2, 2)
# 721 Batch accuracy (training): 82.91635
#  (99, 2, 2)
# 722 Batch accuracy (training): 82.777725
#  (99, 2, 2)
# 723 Batch accuracy (training): 82.63965
#  (99, 2, 2)
# 724 Batch accuracy (training): 82.502144
#  (99, 2, 2)
# 725 Batch accuracy (training): 82.36517
#  (99, 2, 2)
# 726 Batch accuracy (training): 82.22874
#  (99, 2, 2)
# 727 Batch accuracy (training): 82.092865
#  (99, 2, 2)
# 728 Batch accuracy (training): 81.95752
#  (99, 2, 2)
# 729 Batch accuracy (training): 81.82273
#  (99, 2, 2)
# 730 Batch accuracy (training): 81.68846
#  (99, 2, 2)
# 731 Batch accuracy (training): 81.55473
#  (99, 2, 2)
# 732 Batch accuracy (training): 81.42157
#  (99, 2, 2)
# 733 Batch accuracy (training): 81.2889
#  (99, 2, 2)
# 734 Batch accuracy (training): 81.156784
#  (99, 2, 2)
# 735 Batch accuracy (training): 81.025185
#  (99, 2, 2)
# 736 Batch accuracy (training): 80.89412
#  (99, 2, 2)
# 737 Batch accuracy (training): 80.76358
#  (99, 2, 2)
# 738 Batch accuracy (training): 80.63355
#  (99, 2, 2)
# 739 Batch accuracy (training): 80.50404
#  (99, 2, 2)
# 740 Batch accuracy (training): 80.375046
#  (99, 2, 2)
# 741 Batch accuracy (training): 80.24658
#  (99, 2, 2)
# 742 Batch accuracy (training): 80.118614
#  (99, 2, 2)
# 743 Batch accuracy (training): 79.99117
#  (99, 2, 2)
# 744 Batch accuracy (training): 79.86422
#  (99, 2, 2)
# 745 Batch accuracy (training): 79.73779
#  (99, 2, 2)
# 746 Batch accuracy (training): 79.61188
#  (99, 2, 2)
# 747 Batch accuracy (training): 79.48644
#  (99, 2, 2)
# 748 Batch accuracy (training): 79.36154
#  (99, 2, 2)
# 749 Batch accuracy (training): 79.23711
#  (99, 2, 2)
# 750 Batch accuracy (training): 79.11318
#  (99, 2, 2)
# 751 Batch accuracy (training): 78.989746
#  (99, 2, 2)
# 752 Batch accuracy (training): 78.86681
#  (99, 2, 2)
# 753 Batch accuracy (training): 78.74438
#  (99, 2, 2)
# 754 Batch accuracy (training): 78.62241
#  (99, 2, 2)
# 755 Batch accuracy (training): 78.50094
#  (99, 2, 2)
# 756 Batch accuracy (training): 78.37996
#  (99, 2, 2)
# 757 Batch accuracy (training): 78.25947
#  (99, 2, 2)
# 758 Batch accuracy (training): 78.139435
#  (99, 2, 2)
# 759 Batch accuracy (training): 78.0199
#  (99, 2, 2)
# 760 Batch accuracy (training): 77.90085
#  (99, 2, 2)
# 761 Batch accuracy (training): 77.78226
#  (99, 2, 2)
# 762 Batch accuracy (training): 77.664154
#  (99, 2, 2)
# 763 Batch accuracy (training): 77.5465
#  (99, 2, 2)
# 764 Batch accuracy (training): 77.42933
#  (99, 2, 2)
# 765 Batch accuracy (training): 77.31264
#  (99, 2, 2)
# 766 Batch accuracy (training): 77.19639
#  (99, 2, 2)
# 767 Batch accuracy (training): 77.08062
#  (99, 2, 2)
# 768 Batch accuracy (training): 76.965324
#  (99, 2, 2)
# 769 Batch accuracy (training): 76.85047
#  (99, 2, 2)
# 770 Batch accuracy (training): 76.736084
#  (99, 2, 2)
# 771 Batch accuracy (training): 76.622154
#  (99, 2, 2)
# 772 Batch accuracy (training): 76.50867
#  (99, 2, 2)
# 773 Batch accuracy (training): 76.39567
#  (99, 2, 2)
# 774 Batch accuracy (training): 76.28308
#  (99, 2, 2)
# 775 Batch accuracy (training): 76.17097
#  (99, 2, 2)
# 776 Batch accuracy (training): 76.059296
#  (99, 2, 2)
# 777 Batch accuracy (training): 75.948074
#  (99, 2, 2)
# 778 Batch accuracy (training): 75.837296
#  (99, 2, 2)
# 779 Batch accuracy (training): 75.72696
#  (99, 2, 2)
# 780 Batch accuracy (training): 75.61705
#  (99, 2, 2)
# 781 Batch accuracy (training): 75.50759
#  (99, 2, 2)
# 782 Batch accuracy (training): 75.39857
#  (99, 2, 2)
# 783 Batch accuracy (training): 75.28997
#  (99, 2, 2)
# 784 Batch accuracy (training): 75.181816
#  (99, 2, 2)
# 785 Batch accuracy (training): 75.0741
#  (99, 2, 2)
# 786 Batch accuracy (training): 74.96682
#  (99, 2, 2)
# 787 Batch accuracy (training): 74.85995
#  (99, 2, 2)
# 788 Batch accuracy (training): 74.753525
#  (99, 2, 2)
# 789 Batch accuracy (training): 74.64751
#  (99, 2, 2)
# 790 Batch accuracy (training): 74.54192
#  (99, 2, 2)
# 791 Batch accuracy (training): 74.43677
#  (99, 2, 2)
# 792 Batch accuracy (training): 74.33201
#  (99, 2, 2)
# 793 Batch accuracy (training): 74.22768
#  (99, 2, 2)
# 794 Batch accuracy (training): 74.12378
#  (99, 2, 2)
# 795 Batch accuracy (training): 74.020294
#  (99, 2, 2)
# 796 Batch accuracy (training): 73.9172
#  (99, 2, 2)
# 797 Batch accuracy (training): 73.81453
#  (99, 2, 2)
# 798 Batch accuracy (training): 73.71229
#  (99, 2, 2)
# 799 Batch accuracy (training): 73.61044
#  (99, 2, 2)
# 800 Batch accuracy (training): 73.508995
#  (99, 2, 2)
# 801 Batch accuracy (training): 73.407974
#  (99, 2, 2)
# 802 Batch accuracy (training): 73.307335
#  (99, 2, 2)
# 803 Batch accuracy (training): 73.2071
#  (99, 2, 2)
# 804 Batch accuracy (training): 73.10728
#  (99, 2, 2)
# 805 Batch accuracy (training): 73.007835
#  (99, 2, 2)
# 806 Batch accuracy (training): 72.9088
#  (99, 2, 2)
# 807 Batch accuracy (training): 72.81017
#  (99, 2, 2)
# 808 Batch accuracy (training): 72.71192
#  (99, 2, 2)
# 809 Batch accuracy (training): 72.61408
#  (99, 2, 2)
# 810 Batch accuracy (training): 72.51662
#  (99, 2, 2)
# 811 Batch accuracy (training): 72.41955
#  (99, 2, 2)
# 812 Batch accuracy (training): 72.32286
#  (99, 2, 2)
# 813 Batch accuracy (training): 72.22658
#  (99, 2, 2)
# 814 Batch accuracy (training): 72.13065
#  (99, 2, 2)
# 815 Batch accuracy (training): 72.03513
#  (99, 2, 2)
# 816 Batch accuracy (training): 71.93997
#  (99, 2, 2)
# 817 Batch accuracy (training): 71.84522
#  (99, 2, 2)
# 818 Batch accuracy (training): 71.75084
#  (99, 2, 2)
# 819 Batch accuracy (training): 71.65682
#  (99, 2, 2)
# 820 Batch accuracy (training): 71.563194
#  (99, 2, 2)
# 821 Batch accuracy (training): 71.46992
#  (99, 2, 2)
# 822 Batch accuracy (training): 71.377045
#  (99, 2, 2)
# 823 Batch accuracy (training): 71.28451
#  (99, 2, 2)
# 824 Batch accuracy (training): 71.19238
#  (99, 2, 2)
# 825 Batch accuracy (training): 71.1006
#  (99, 2, 2)
# 826 Batch accuracy (training): 71.0092
#  (99, 2, 2)
# 827 Batch accuracy (training): 70.91813
#  (99, 2, 2)
# 828 Batch accuracy (training): 70.82745
#  (99, 2, 2)
# 829 Batch accuracy (training): 70.73713
#  (99, 2, 2)
# 830 Batch accuracy (training): 70.64718
#  (99, 2, 2)
# 831 Batch accuracy (training): 70.55758
#  (99, 2, 2)
# 832 Batch accuracy (training): 70.46832
#  (99, 2, 2)
# 833 Batch accuracy (training): 70.379456
#  (99, 2, 2)
# 834 Batch accuracy (training): 70.29091
#  (99, 2, 2)
# 835 Batch accuracy (training): 70.20274
#  (99, 2, 2)
# 836 Batch accuracy (training): 70.114914
#  (99, 2, 2)
# 837 Batch accuracy (training): 70.02744
#  (99, 2, 2)
# 838 Batch accuracy (training): 69.94032
#  (99, 2, 2)
# 839 Batch accuracy (training): 69.85354
#  (99, 2, 2)
# 840 Batch accuracy (training): 69.76711
#  (99, 2, 2)
# 841 Batch accuracy (training): 69.68103
#  (99, 2, 2)
# 842 Batch accuracy (training): 69.59529
#  (99, 2, 2)
# 843 Batch accuracy (training): 69.50991
#  (99, 2, 2)
# 844 Batch accuracy (training): 69.42484
#  (99, 2, 2)
# 845 Batch accuracy (training): 69.340126
#  (99, 2, 2)
# 846 Batch accuracy (training): 69.25576
#  (99, 2, 2)
# 847 Batch accuracy (training): 69.17171
#  (99, 2, 2)
# 848 Batch accuracy (training): 69.08801
#  (99, 2, 2)
# 849 Batch accuracy (training): 69.00463
#  (99, 2, 2)
# 850 Batch accuracy (training): 68.9216
#  (99, 2, 2)
# 851 Batch accuracy (training): 68.8389
#  (99, 2, 2)
# 852 Batch accuracy (training): 68.75652
#  (99, 2, 2)
# 853 Batch accuracy (training): 68.674484
#  (99, 2, 2)
# 854 Batch accuracy (training): 68.59276
#  (99, 2, 2)
# 855 Batch accuracy (training): 68.51138
#  (99, 2, 2)
# 856 Batch accuracy (training): 68.430305
#  (99, 2, 2)
# 857 Batch accuracy (training): 68.34956
#  (99, 2, 2)
# 858 Batch accuracy (training): 68.269135
#  (99, 2, 2)
# 859 Batch accuracy (training): 68.18905
#  (99, 2, 2)
# 860 Batch accuracy (training): 68.10927
#  (99, 2, 2)
# 861 Batch accuracy (training): 68.029816
#  (99, 2, 2)
# 862 Batch accuracy (training): 67.95066
#  (99, 2, 2)
# 863 Batch accuracy (training): 67.87185
#  (99, 2, 2)
# 864 Batch accuracy (training): 67.79333
#  (99, 2, 2)
# 865 Batch accuracy (training): 67.71514
#  (99, 2, 2)
# 866 Batch accuracy (training): 67.63727
#  (99, 2, 2)
# 867 Batch accuracy (training): 67.559685
#  (99, 2, 2)
# 868 Batch accuracy (training): 67.48242
#  (99, 2, 2)
# 869 Batch accuracy (training): 67.405464
#  (99, 2, 2)
# 870 Batch accuracy (training): 67.32883
#  (99, 2, 2)
# 871 Batch accuracy (training): 67.25248
#  (99, 2, 2)
# 872 Batch accuracy (training): 67.176445
#  (99, 2, 2)
# 873 Batch accuracy (training): 67.100716
#  (99, 2, 2)
# 874 Batch accuracy (training): 67.02528
#  (99, 2, 2)
# 875 Batch accuracy (training): 66.950165
#  (99, 2, 2)
# 876 Batch accuracy (training): 66.87533
#  (99, 2, 2)
# 877 Batch accuracy (training): 66.800804
#  (99, 2, 2)
# 878 Batch accuracy (training): 66.726585
#  (99, 2, 2)
# 879 Batch accuracy (training): 66.65263
#  (99, 2, 2)
# 880 Batch accuracy (training): 66.579
#  (99, 2, 2)
# 881 Batch accuracy (training): 66.50567
#  (99, 2, 2)
# 882 Batch accuracy (training): 66.43261
#  (99, 2, 2)
# 883 Batch accuracy (training): 66.359856
#  (99, 2, 2)
# 884 Batch accuracy (training): 66.28739
#  (99, 2, 2)
# 885 Batch accuracy (training): 66.2152
#  (99, 2, 2)
# 886 Batch accuracy (training): 66.143326
#  (99, 2, 2)
# 887 Batch accuracy (training): 66.07172
#  (99, 2, 2)
# 888 Batch accuracy (training): 66.0004
#  (99, 2, 2)
# 889 Batch accuracy (training): 65.92936
#  (99, 2, 2)
# 890 Batch accuracy (training): 65.85861
#  (99, 2, 2)
# 891 Batch accuracy (training): 65.788155
#  (99, 2, 2)
# 892 Batch accuracy (training): 65.71798
#  (99, 2, 2)
# 893 Batch accuracy (training): 65.64807
#  (99, 2, 2)
# 894 Batch accuracy (training): 65.578445
#  (99, 2, 2)
# 895 Batch accuracy (training): 65.509094
#  (99, 2, 2)
# 896 Batch accuracy (training): 65.44002
#  (99, 2, 2)
# ...
#  (99, 2, 2)
# 5582 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5583 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5584 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5585 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5586 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5587 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5588 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5589 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5590 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5591 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5592 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5593 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5594 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5595 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5596 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5597 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5598 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5599 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5600 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5601 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5602 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5603 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5604 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5605 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5606 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5607 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5608 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5609 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5610 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5611 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5612 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5613 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5614 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5615 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5616 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5617 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5618 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5619 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5620 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5621 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5622 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5623 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5624 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5625 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5626 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5627 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5628 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5629 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5630 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5631 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5632 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5633 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5634 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5635 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5636 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5637 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5638 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5639 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5640 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5641 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5642 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5643 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5644 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5645 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5646 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5647 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5648 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5649 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5650 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5651 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5652 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5653 Batch accuracy (training): 48.22476
#  (99, 2, 2)
# 5654 Batch accuracy (training): 48.22476
#  (99, 2, 2)
# 5655 Batch accuracy (training): 48.22476
#  (99, 2, 2)
# 5656 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5657 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5658 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5659 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5660 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5661 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5662 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5663 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5664 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5665 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5666 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5667 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5668 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5669 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5670 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5671 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5672 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5673 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5674 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5675 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5676 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5677 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5678 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5679 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5680 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5681 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5682 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5683 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5684 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5685 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5686 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5687 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5688 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5689 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5690 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5691 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5692 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5693 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5694 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5695 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5696 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5697 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5698 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5699 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5700 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5701 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5702 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5703 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5704 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5705 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5706 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5707 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5708 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5709 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5710 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5711 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5712 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5713 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5714 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5715 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5716 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5717 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5718 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5719 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5720 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5721 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5722 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5723 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5724 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5725 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5726 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5727 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5728 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5729 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5730 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5731 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5732 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5733 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5734 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5735 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5736 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5737 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5738 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5739 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5740 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5741 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5742 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5743 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5744 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5745 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5746 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5747 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5748 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5749 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5750 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5751 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5752 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5753 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5754 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5755 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5756 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5757 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5758 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5759 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5760 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5761 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5762 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5763 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5764 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5765 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5766 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5767 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5768 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5769 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5770 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5771 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5772 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5773 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5774 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5775 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5776 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5777 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5778 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5779 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5780 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5781 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5782 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5783 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5784 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5785 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5786 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5787 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5788 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5789 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5790 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5791 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5792 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5793 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5794 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5795 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5796 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5797 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5798 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5799 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5800 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5801 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5802 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5803 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5804 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5805 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5806 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5807 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5808 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5809 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5810 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5811 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5812 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5813 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5814 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5815 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5816 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5817 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5818 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5819 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5820 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5821 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5822 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5823 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5824 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5825 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5826 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5827 Batch accuracy (training): 48.224777
#  (99, 2, 2)
# 5828 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5829 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5830 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5831 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5832 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5833 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5834 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5835 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5836 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5837 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5838 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5839 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5840 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5841 Batch accuracy (training): 48.224762
#  (99, 2, 2)
# 5842 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5843 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5844 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5845 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5846 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5847 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5848 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5849 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5850 Batch accuracy (training): 48.224766
#  (99, 2, 2)
# 5851 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5852 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5853 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5854 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5855 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5856 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5857 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5858 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5859 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5860 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5861 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5862 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5863 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5864 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5865 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5866 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5867 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5868 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5869 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5870 Batch accuracy (training): 48.224773
#  (99, 2, 2)
# 5871 Batch accuracy (training): 48.224773
#  (99, 2, 2)
